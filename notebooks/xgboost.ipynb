# %%
from typing import List

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import xgboost as xgb
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    confusion_matrix,
    roc_auc_score,
)
from torch_geometric.data import Data

import wandb
from soccerai.data.converters import ConnectionMode
from soccerai.data.converters.shot_prediction_converter import (
    ShotPredictionGraphConverter,
)
from wandb.integration.xgboost import WandbCallback

converter = ShotPredictionGraphConverter(ConnectionMode.FULLY_CONNECTED)

# %%
df = pl.read_parquet(
    "/home/fbaiocchi/soccerai/soccerai/data/resources/raw/dataset.parquet"
)
print("Raw dataset shape:", df.shape)
print(df.columns)
# Out:
# Raw dataset shape: (428698, 50)
# ['index', 'gameId', 'gameEventId', 'possessionEventId', 'startTime', 'endTime', 'duration', 'gameEventType', 'possessionEventType', 'teamName', 'playerName', 'videoUrl', 'frameTime', 'label', 'index_right', 'gameId_right', 'team', 'x', 'y', 'z', 'jerseyNum', 'visibility', 'velocity', 'direction', 'homeTeamName', 'awayTeamName', 'homeTeamStartLeft', 'startPeriod2', 'playerId', 'playerName_right', 'playerRole', 'Full Name', 'Height', 'Weight', 'Age Info', 'goals', 'shots', 'shots_on_target', 'shots_on_target_pct', 'shots_per90', 'shots_on_target_per90', 'goals_per_shot', 'goals_per_shot_on_target', 'average_shot_distance', 'pens_made', 'pens_att', 'Market Value', 'birth_date', 'age', 'height_cm']

# %%
def split_dataframe_by_event_keys(
    df: pl.DataFrame,
    key_cols: list[str] = ["gameEventId", "possessionEventId"],
    val_ratio: float = 0.2,
) -> tuple[pl.DataFrame, pl.DataFrame]:
    event_keys_df = df.select(key_cols).unique().sort(key_cols)  # important!
    num_events = event_keys_df.height

    train_end_idx = int((1.0 - val_ratio) * num_events)

    train_event_keys = event_keys_df.slice(0, train_end_idx)
    val_event_keys = event_keys_df.slice(train_end_idx, num_events)

    train_df = df.join(train_event_keys, on=key_cols, how="semi")
    val_df = df.join(val_event_keys, on=key_cols, how="semi")
    return train_df, val_df


train_df, val_df = split_dataframe_by_event_keys(df, val_ratio=0.2)
print("Train rows:", train_df.height, " Val rows:", val_df.height)
# Out:
# Train rows: 342953  Val rows: 85745

# %%
converter = ShotPredictionGraphConverter(ConnectionMode.FULLY_CONNECTED)

train_graphs: List[Data] = converter.convert_dataframe_to_data_list(train_df)
val_graphs: List[Data] = converter.convert_dataframe_to_data_list(val_df)


# [22, d] → [22*d]
def flatten_graphs(graphs: List[Data]):
    X = np.stack([g.x.numpy().reshape(-1) for g in graphs], axis=0)
    y = np.array([float(g.y.item()) for g in graphs])
    return X, y


X_train, y_train = flatten_graphs(train_graphs)
X_val, y_val = flatten_graphs(val_graphs)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:  ", X_val.shape, "y_val:", y_val.shape)
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 converter = ShotPredictionGraphConverter(ConnectionMode.FULLY_CONNECTED)
# ----> 3 train_graphs: List[Data] = converter.convert_dataframe_to_data_list(train_df)
#       4 val_graphs: List[Data] = converter.convert_dataframe_to_data_list(val_df)
#       7 # [22, d] → [22*d]
#
# File ~/soccerai/soccerai/data/converters/shot_prediction_converter.py:111, in ShotPredictionGraphConverter.convert_dataframe_to_data_list(self, df)
#     110 def convert_dataframe_to_data_list(self, df: pl.DataFrame) -> List[Data]:
# --> 111     processed_df = self._preprocess_dataframe(df)
#     113     data_list = []
#     115     for _, event_df in processed_df.group_by(["gameEventId", "possessionEventId"]):
#
# File ~/soccerai/soccerai/data/converters/shot_prediction_converter.py:68, in ShotPredictionGraphConverter._preprocess_dataframe(self, df)
#      65 df = df.filter(pl.col("possessionEventType") != "SH")
#      66 df = df.filter(pl.col("playerName").is_not_null())
# ---> 68 df = df.with_columns(
#      69     [
#      70         (
#      71             pl.col("frameTime").str.split(":").list.get(0).cast(pl.UInt16) * 60
#      72             + pl.col("frameTime").str.split(":").list.get(1).cast(pl.UInt16)
#      73         ).alias("frameTime"),
#      74         (
#      75             pl.when(pl.col("playerName") == pl.col("playerName_right"))
#      76             .then(1)
#      77             .otherwise(0)
#      78         ).alias("ballPossession"),
#      79         (pl.col("Weight").str.replace("kg", "").cast(pl.UInt8)),
#      80         (pl.col("height_cm").cast(pl.UInt8)),
#      81     ]
#      82 )
#      84 df = df.drop(["playerName", "playerName_right"])
#      85 # df = add_goal_features(df)
#
# File ~/miniconda3/envs/soccerai/lib/python3.11/site-packages/polars/dataframe/frame.py:9805, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9659 def with_columns(
#    9660     self,
#    9661     *exprs: IntoExpr | Iterable[IntoExpr],
#    9662     **named_exprs: IntoExpr,
#    9663 ) -> DataFrame:
#    9664     """
#    9665     Add columns to this DataFrame.
#    9666
#    (...)
#    9803     └─────┴──────┴─────────────┘
#    9804     """
# -> 9805     return self.lazy().with_columns(*exprs, **named_exprs).collect(_eager=True)
#
# File ~/miniconda3/envs/soccerai/lib/python3.11/site-packages/polars/_utils/deprecation.py:88, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      85     del kwargs["streaming"]
#      86     kwargs["engine"] = "old-streaming"
# ---> 88 return function(*args, **kwargs)
#
# File ~/miniconda3/envs/soccerai/lib/python3.11/site-packages/polars/lazyframe/frame.py:2188, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, _check_order, _eager, **_kwargs)
#    2186 # Only for testing purposes
#    2187 callback = _kwargs.get("post_opt_callback", callback)
# -> 2188 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: Weight
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
# DF ["gameEventId", "possessionEventId", "duration", "possessionEventType", ...]; PROJECT */16 COLUMNS

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

# %%
wandb.init(
    project="soccerai",
    name="xgb-many-rounds",
    reinit=True,
    config={
        "objective": "binary:logistic",
        "eval_metric": ["auc", "logloss"],
        "eta": 0.005,
        "max_depth": 1,
        "subsample": 0.8,
        "colsample_bytree": 0.8,
        "seed": 42,
        "num_boost_round": 1000,
    },
)
cfg = wandb.config

dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

params = {
    "objective": cfg.objective,
    "eval_metric": cfg.eval_metric,
    "eta": cfg.eta,
    "max_depth": cfg.max_depth,
    "subsample": cfg.subsample,
    "colsample_bytree": cfg.colsample_bytree,
    "seed": cfg.seed,
}

bst = xgb.train(
    params,
    dtrain,
    num_boost_round=cfg.num_boost_round,
    evals=[(dtrain, "train"), (dval, "validation")],
    callbacks=[WandbCallback()],
)

train_probs = bst.predict(dtrain)
val_probs = bst.predict(dval)

train_preds = (train_probs > 0.5).astype(int)
val_preds = (val_probs > 0.5).astype(int)

wandb.log(
    {
        "train/accuracy": accuracy_score(y_train, train_preds),
        "val/accuracy": accuracy_score(y_val, val_preds),
        "val/roc_auc": roc_auc_score(y_val, val_probs),
    }
)


def log_cm(y_true, y_pred, tag):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    fig, ax = plt.subplots(figsize=(4, 4))
    disp = ConfusionMatrixDisplay(cm, display_labels=["no_shot", "shot"])
    disp.plot(cmap="Blues", ax=ax, colorbar=False)
    ax.set_title(tag)
    wandb.log({tag.replace(" ", "_").lower(): wandb.Image(fig)})
    plt.close(fig)


log_cm(y_train, train_preds, "Train Confusion Matrix")
log_cm(y_val, val_preds, "Val   Confusion Matrix")

wandb.finish()

# %%
node_cols = [
    c
    for c in converter._preprocess_dataframe(train_df).columns
    if c not in ("gameEventId", "possessionEventId", "label")
]
node_feature_count = train_graphs[0].x.shape[1]
assert len(node_cols) == node_feature_count

# %%
flat_feat_names = [f"{node:02d}_{feat}" for node in range(22) for feat in node_cols]
total_flat = flat_feat_names.__len__()
assert total_flat == X_train.shape[1]

# %%
importance_dict = bst.get_score(importance_type="gain")
real_names, scores = [], []
for fx, score in importance_dict.items():
    idx = int(fx[1:])  # 'f27' → 27
    real_names.append(flat_feat_names[idx])
    scores.append(score)

# %%
top_k = 20
order = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)
for i in order[:top_k]:
    print(f"{real_names[i]:<30} gain = {scores[i]:.3f}")

# %%
top_names = [real_names[i] for i in order[:top_k]]
top_scores = [scores[i] for i in order[:top_k]]

fig, ax = plt.subplots(figsize=(6, 4))
ax.barh(range(len(top_names)), top_scores, align="center")
ax.set_yticks(range(len(top_names)))
ax.set_yticklabels(top_names)
ax.invert_yaxis()
ax.set_xlabel("Importance (gain)")
ax.set_title("Top 20 Feature importances")
plt.tight_layout()

# %%
# xgboost k-fold CV con logging su W&B

import xgboost as xgb
from sklearn.model_selection import StratifiedKFold

import wandb
from wandb.integration.xgboost import WandbCallback

wandb.init(
    project="soccerai",
    name="xgb-kfold",
    config=dict(
        objective="binary:logistic",
        eval_metric=["auc", "logloss"],
        eta=0.05,
        max_depth=4,
        subsample=0.8,
        colsample_bytree=0.8,
        seed=42,
        num_boost_round=1000,
        early_stopping_rounds=20,
        n_splits=5,
    ),
)
cfg = wandb.config

X_all = np.vstack([X_train, X_val])
y_all = np.concatenate([y_train, y_val])

params = dict(
    objective=cfg.objective,
    eval_metric=cfg.eval_metric,
    eta=cfg.eta,
    max_depth=cfg.max_depth,
    subsample=cfg.subsample,
    colsample_bytree=cfg.colsample_bytree,
    seed=cfg.seed,
)

skf = StratifiedKFold(
    n_splits=cfg.n_splits,
    shuffle=True,
    random_state=cfg.seed,
)

for fold, (tr_idx, va_idx) in enumerate(skf.split(X_all, y_all), 1):
    print(f"Fold {fold}/{cfg.n_splits}")

    dtrain = xgb.DMatrix(X_all[tr_idx], label=y_all[tr_idx])
    dval = xgb.DMatrix(X_all[va_idx], label=y_all[va_idx])

    bst = xgb.train(
        params,
        dtrain,
        num_boost_round=cfg.num_boost_round,
        evals=[(dtrain, "train"), (dval, f"fold{fold}")],
        early_stopping_rounds=cfg.early_stopping_rounds,
        callbacks=[WandbCallback(log_model=False)],
    )

    wandb.log(
        {
            f"fold{fold}/best_iteration": bst.best_iteration,
            f"fold{fold}/best_score": bst.best_score,
        }
    )

wandb.finish()
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/fbaiocchi/soccerai/notebooks/wandb/run-20250526_164208-2e4v8aj8</code>
# Syncing run <strong><a href='https://wandb.ai/soccerai/soccerai/runs/2e4v8aj8' target="_blank">xgb-kfold</a></strong> to <a href='https://wandb.ai/soccerai/soccerai' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/soccerai/soccerai' target="_blank">https://wandb.ai/soccerai/soccerai</a>
#  View run at <a href='https://wandb.ai/soccerai/soccerai/runs/2e4v8aj8' target="_blank">https://wandb.ai/soccerai/soccerai/runs/2e4v8aj8</a>
# Fold 1/5
# [0]	train-auc:0.64485	train-logloss:0.61131	fold1-auc:0.63381	fold1-logloss:0.61168
# [1]	train-auc:0.68800	train-logloss:0.60749	fold1-auc:0.67568	fold1-logloss:0.60814
# [2]	train-auc:0.69913	train-logloss:0.60420	fold1-auc:0.67982	fold1-logloss:0.60535
# [3]	train-auc:0.70608	train-logloss:0.60079	fold1-auc:0.68604	fold1-logloss:0.60262
# [4]	train-auc:0.71590	train-logloss:0.59800	fold1-auc:0.69529	fold1-logloss:0.60022
# [5]	train-auc:0.72018	train-logloss:0.59546	fold1-auc:0.69726	fold1-logloss:0.59821
# [6]	train-auc:0.72487	train-logloss:0.59260	fold1-auc:0.69679	fold1-logloss:0.59589
# [7]	train-auc:0.73534	train-logloss:0.59030	fold1-auc:0.71062	fold1-logloss:0.59363
# [8]	train-auc:0.74050	train-logloss:0.58780	fold1-auc:0.71379	fold1-logloss:0.59163
# [9]	train-auc:0.74345	train-logloss:0.58541	fold1-auc:0.71462	fold1-logloss:0.58991
# [10]	train-auc:0.74634	train-logloss:0.58334	fold1-auc:0.71787	fold1-logloss:0.58811
# [11]	train-auc:0.75055	train-logloss:0.58067	fold1-auc:0.71961	fold1-logloss:0.58589
# [12]	train-auc:0.75347	train-logloss:0.57833	fold1-auc:0.72025	fold1-logloss:0.58401
# [13]	train-auc:0.75608	train-logloss:0.57655	fold1-auc:0.72261	fold1-logloss:0.58243
# [14]	train-auc:0.75613	train-logloss:0.57465	fold1-auc:0.72136	fold1-logloss:0.58097
# [15]	train-auc:0.75945	train-logloss:0.57274	fold1-auc:0.72437	fold1-logloss:0.57954
# [16]	train-auc:0.76080	train-logloss:0.57082	fold1-auc:0.72547	fold1-logloss:0.57788
# [17]	train-auc:0.76354	train-logloss:0.56921	fold1-auc:0.72812	fold1-logloss:0.57653
# [18]	train-auc:0.76713	train-logloss:0.56744	fold1-auc:0.73005	fold1-logloss:0.57526
# [19]	train-auc:0.77018	train-logloss:0.56536	fold1-auc:0.73354	fold1-logloss:0.57344
# [20]	train-auc:0.77149	train-logloss:0.56345	fold1-auc:0.73555	fold1-logloss:0.57178
# [21]	train-auc:0.77391	train-logloss:0.56247	fold1-auc:0.73716	fold1-logloss:0.57105
# [22]	train-auc:0.77483	train-logloss:0.56079	fold1-auc:0.73832	fold1-logloss:0.56959
# [23]	train-auc:0.77855	train-logloss:0.55884	fold1-auc:0.73987	fold1-logloss:0.56811
# [24]	train-auc:0.78007	train-logloss:0.55748	fold1-auc:0.74035	fold1-logloss:0.56737
# [25]	train-auc:0.78225	train-logloss:0.55618	fold1-auc:0.74109	fold1-logloss:0.56644
# [26]	train-auc:0.78455	train-logloss:0.55501	fold1-auc:0.74198	fold1-logloss:0.56582
# [27]	train-auc:0.78611	train-logloss:0.55363	fold1-auc:0.74234	fold1-logloss:0.56497
# [28]	train-auc:0.78779	train-logloss:0.55256	fold1-auc:0.74371	fold1-logloss:0.56409
# [29]	train-auc:0.79053	train-logloss:0.55087	fold1-auc:0.74547	fold1-logloss:0.56298
# [30]	train-auc:0.79367	train-logloss:0.54947	fold1-auc:0.74796	fold1-logloss:0.56193
# [31]	train-auc:0.79501	train-logloss:0.54811	fold1-auc:0.75017	fold1-logloss:0.56082
# [32]	train-auc:0.79666	train-logloss:0.54634	fold1-auc:0.75118	fold1-logloss:0.55953
# [33]	train-auc:0.79685	train-logloss:0.54488	fold1-auc:0.75087	fold1-logloss:0.55855
# [34]	train-auc:0.79790	train-logloss:0.54395	fold1-auc:0.75139	fold1-logloss:0.55792
# [35]	train-auc:0.79962	train-logloss:0.54313	fold1-auc:0.75314	fold1-logloss:0.55721
# [36]	train-auc:0.80189	train-logloss:0.54167	fold1-auc:0.75523	fold1-logloss:0.55601
# [37]	train-auc:0.80319	train-logloss:0.54094	fold1-auc:0.75613	fold1-logloss:0.55540
# [38]	train-auc:0.80482	train-logloss:0.53980	fold1-auc:0.75694	fold1-logloss:0.55461
# [39]	train-auc:0.80686	train-logloss:0.53833	fold1-auc:0.75809	fold1-logloss:0.55372
# [40]	train-auc:0.80881	train-logloss:0.53700	fold1-auc:0.75974	fold1-logloss:0.55265
# [41]	train-auc:0.80993	train-logloss:0.53625	fold1-auc:0.76021	fold1-logloss:0.55215
# [42]	train-auc:0.81321	train-logloss:0.53446	fold1-auc:0.76221	fold1-logloss:0.55085
# [43]	train-auc:0.81498	train-logloss:0.53313	fold1-auc:0.76365	fold1-logloss:0.54980
# [44]	train-auc:0.81618	train-logloss:0.53237	fold1-auc:0.76453	fold1-logloss:0.54919
# [45]	train-auc:0.81735	train-logloss:0.53121	fold1-auc:0.76527	fold1-logloss:0.54845
# [46]	train-auc:0.81822	train-logloss:0.53052	fold1-auc:0.76632	fold1-logloss:0.54787
# [47]	train-auc:0.81940	train-logloss:0.52964	fold1-auc:0.76737	fold1-logloss:0.54713
# [48]	train-auc:0.82205	train-logloss:0.52833	fold1-auc:0.76897	fold1-logloss:0.54635
# [49]	train-auc:0.82201	train-logloss:0.52726	fold1-auc:0.76969	fold1-logloss:0.54538
# [50]	train-auc:0.82398	train-logloss:0.52614	fold1-auc:0.77183	fold1-logloss:0.54444
# [51]	train-auc:0.82537	train-logloss:0.52507	fold1-auc:0.77317	fold1-logloss:0.54350
# [52]	train-auc:0.82706	train-logloss:0.52389	fold1-auc:0.77448	fold1-logloss:0.54261
# [53]	train-auc:0.82795	train-logloss:0.52296	fold1-auc:0.77482	fold1-logloss:0.54201
# [54]	train-auc:0.82973	train-logloss:0.52164	fold1-auc:0.77664	fold1-logloss:0.54094
# [55]	train-auc:0.83149	train-logloss:0.52056	fold1-auc:0.77694	fold1-logloss:0.54043
# [56]	train-auc:0.83241	train-logloss:0.51973	fold1-auc:0.77787	fold1-logloss:0.53969
# [57]	train-auc:0.83408	train-logloss:0.51885	fold1-auc:0.77908	fold1-logloss:0.53915
# [58]	train-auc:0.83555	train-logloss:0.51751	fold1-auc:0.78078	fold1-logloss:0.53802
# [59]	train-auc:0.83761	train-logloss:0.51632	fold1-auc:0.78252	fold1-logloss:0.53707
# [60]	train-auc:0.83913	train-logloss:0.51532	fold1-auc:0.78390	fold1-logloss:0.53624
# [61]	train-auc:0.84043	train-logloss:0.51447	fold1-auc:0.78475	fold1-logloss:0.53575
# [62]	train-auc:0.84165	train-logloss:0.51381	fold1-auc:0.78540	fold1-logloss:0.53521
# [63]	train-auc:0.84280	train-logloss:0.51315	fold1-auc:0.78596	fold1-logloss:0.53477
# [64]	train-auc:0.84367	train-logloss:0.51209	fold1-auc:0.78591	fold1-logloss:0.53421
# [65]	train-auc:0.84498	train-logloss:0.51090	fold1-auc:0.78669	fold1-logloss:0.53354
# [66]	train-auc:0.84564	train-logloss:0.51028	fold1-auc:0.78744	fold1-logloss:0.53307
# [67]	train-auc:0.84693	train-logloss:0.50913	fold1-auc:0.78815	fold1-logloss:0.53235
# [68]	train-auc:0.84837	train-logloss:0.50829	fold1-auc:0.78862	fold1-logloss:0.53189
# [69]	train-auc:0.84912	train-logloss:0.50775	fold1-auc:0.78905	fold1-logloss:0.53162
# [70]	train-auc:0.84967	train-logloss:0.50715	fold1-auc:0.78938	fold1-logloss:0.53117
# [71]	train-auc:0.85066	train-logloss:0.50653	fold1-auc:0.78992	fold1-logloss:0.53080
# [72]	train-auc:0.85196	train-logloss:0.50529	fold1-auc:0.79090	fold1-logloss:0.52999
# [73]	train-auc:0.85323	train-logloss:0.50411	fold1-auc:0.79244	fold1-logloss:0.52908
# [74]	train-auc:0.85377	train-logloss:0.50340	fold1-auc:0.79355	fold1-logloss:0.52838
# [75]	train-auc:0.85570	train-logloss:0.50233	fold1-auc:0.79487	fold1-logloss:0.52776
# [76]	train-auc:0.85633	train-logloss:0.50143	fold1-auc:0.79530	fold1-logloss:0.52725
# [77]	train-auc:0.85747	train-logloss:0.50053	fold1-auc:0.79655	fold1-logloss:0.52661
# [78]	train-auc:0.85822	train-logloss:0.49987	fold1-auc:0.79646	fold1-logloss:0.52643
# [79]	train-auc:0.85884	train-logloss:0.49926	fold1-auc:0.79727	fold1-logloss:0.52588
# [80]	train-auc:0.86067	train-logloss:0.49832	fold1-auc:0.79868	fold1-logloss:0.52523
# [81]	train-auc:0.86163	train-logloss:0.49710	fold1-auc:0.79980	fold1-logloss:0.52436
# [82]	train-auc:0.86274	train-logloss:0.49622	fold1-auc:0.80068	fold1-logloss:0.52374
# [83]	train-auc:0.86322	train-logloss:0.49577	fold1-auc:0.80078	fold1-logloss:0.52347
# [84]	train-auc:0.86402	train-logloss:0.49502	fold1-auc:0.80179	fold1-logloss:0.52274
# [85]	train-auc:0.86488	train-logloss:0.49435	fold1-auc:0.80167	fold1-logloss:0.52248
# [86]	train-auc:0.86576	train-logloss:0.49367	fold1-auc:0.80189	fold1-logloss:0.52221
# [87]	train-auc:0.86660	train-logloss:0.49301	fold1-auc:0.80241	fold1-logloss:0.52179
# [88]	train-auc:0.86759	train-logloss:0.49213	fold1-auc:0.80354	fold1-logloss:0.52118
# [89]	train-auc:0.86842	train-logloss:0.49125	fold1-auc:0.80442	fold1-logloss:0.52043
# [90]	train-auc:0.86901	train-logloss:0.49085	fold1-auc:0.80446	fold1-logloss:0.52034
# [91]	train-auc:0.87072	train-logloss:0.48982	fold1-auc:0.80583	fold1-logloss:0.51974
# [92]	train-auc:0.87139	train-logloss:0.48891	fold1-auc:0.80588	fold1-logloss:0.51929
# [93]	train-auc:0.87219	train-logloss:0.48788	fold1-auc:0.80684	fold1-logloss:0.51845
# [94]	train-auc:0.87281	train-logloss:0.48730	fold1-auc:0.80729	fold1-logloss:0.51807
# [95]	train-auc:0.87378	train-logloss:0.48648	fold1-auc:0.80823	fold1-logloss:0.51752
# [96]	train-auc:0.87461	train-logloss:0.48524	fold1-auc:0.80898	fold1-logloss:0.51670
# [97]	train-auc:0.87534	train-logloss:0.48434	fold1-auc:0.80974	fold1-logloss:0.51591
# [98]	train-auc:0.87635	train-logloss:0.48356	fold1-auc:0.81035	fold1-logloss:0.51553
# [99]	train-auc:0.87655	train-logloss:0.48294	fold1-auc:0.81049	fold1-logloss:0.51503
# [100]	train-auc:0.87726	train-logloss:0.48231	fold1-auc:0.81085	fold1-logloss:0.51464
# [101]	train-auc:0.87792	train-logloss:0.48179	fold1-auc:0.81113	fold1-logloss:0.51442
# [102]	train-auc:0.87852	train-logloss:0.48109	fold1-auc:0.81146	fold1-logloss:0.51397
# [103]	train-auc:0.87896	train-logloss:0.48056	fold1-auc:0.81200	fold1-logloss:0.51361
# [104]	train-auc:0.87985	train-logloss:0.47978	fold1-auc:0.81195	fold1-logloss:0.51333
# [105]	train-auc:0.88001	train-logloss:0.47939	fold1-auc:0.81216	fold1-logloss:0.51310
# [106]	train-auc:0.88081	train-logloss:0.47867	fold1-auc:0.81224	fold1-logloss:0.51281
# [107]	train-auc:0.88187	train-logloss:0.47796	fold1-auc:0.81254	fold1-logloss:0.51254
# [108]	train-auc:0.88266	train-logloss:0.47707	fold1-auc:0.81380	fold1-logloss:0.51174
# [109]	train-auc:0.88357	train-logloss:0.47634	fold1-auc:0.81458	fold1-logloss:0.51122
# [110]	train-auc:0.88411	train-logloss:0.47568	fold1-auc:0.81500	fold1-logloss:0.51078
# [111]	train-auc:0.88455	train-logloss:0.47521	fold1-auc:0.81534	fold1-logloss:0.51048
# [112]	train-auc:0.88547	train-logloss:0.47426	fold1-auc:0.81642	fold1-logloss:0.50969
# [113]	train-auc:0.88652	train-logloss:0.47355	fold1-auc:0.81737	fold1-logloss:0.50912
# [114]	train-auc:0.88729	train-logloss:0.47265	fold1-auc:0.81720	fold1-logloss:0.50879
# [115]	train-auc:0.88822	train-logloss:0.47157	fold1-auc:0.81814	fold1-logloss:0.50798
# [116]	train-auc:0.88860	train-logloss:0.47120	fold1-auc:0.81836	fold1-logloss:0.50777
# [117]	train-auc:0.88895	train-logloss:0.47074	fold1-auc:0.81854	fold1-logloss:0.50753
# [118]	train-auc:0.88940	train-logloss:0.47023	fold1-auc:0.81876	fold1-logloss:0.50727
# [119]	train-auc:0.88996	train-logloss:0.46963	fold1-auc:0.81904	fold1-logloss:0.50693
# [120]	train-auc:0.89037	train-logloss:0.46925	fold1-auc:0.81942	fold1-logloss:0.50663
# [121]	train-auc:0.89106	train-logloss:0.46839	fold1-auc:0.82015	fold1-logloss:0.50600
# [122]	train-auc:0.89125	train-logloss:0.46789	fold1-auc:0.82035	fold1-logloss:0.50557
# [123]	train-auc:0.89207	train-logloss:0.46709	fold1-auc:0.82150	fold1-logloss:0.50483
# [124]	train-auc:0.89264	train-logloss:0.46638	fold1-auc:0.82144	fold1-logloss:0.50457
# [125]	train-auc:0.89336	train-logloss:0.46558	fold1-auc:0.82243	fold1-logloss:0.50380
# [126]	train-auc:0.89353	train-logloss:0.46511	fold1-auc:0.82293	fold1-logloss:0.50336
# [127]	train-auc:0.89401	train-logloss:0.46456	fold1-auc:0.82303	fold1-logloss:0.50315
# [128]	train-auc:0.89438	train-logloss:0.46391	fold1-auc:0.82355	fold1-logloss:0.50270
# [129]	train-auc:0.89493	train-logloss:0.46332	fold1-auc:0.82380	fold1-logloss:0.50241
# [130]	train-auc:0.89577	train-logloss:0.46270	fold1-auc:0.82453	fold1-logloss:0.50194
# [131]	train-auc:0.89606	train-logloss:0.46210	fold1-auc:0.82510	fold1-logloss:0.50137
# [132]	train-auc:0.89682	train-logloss:0.46148	fold1-auc:0.82524	fold1-logloss:0.50118
# [133]	train-auc:0.89735	train-logloss:0.46099	fold1-auc:0.82525	fold1-logloss:0.50105
# [134]	train-auc:0.89773	train-logloss:0.46059	fold1-auc:0.82512	fold1-logloss:0.50097
# [135]	train-auc:0.89847	train-logloss:0.46005	fold1-auc:0.82590	fold1-logloss:0.50051
# [136]	train-auc:0.89937	train-logloss:0.45913	fold1-auc:0.82683	fold1-logloss:0.49980
# [137]	train-auc:0.90002	train-logloss:0.45863	fold1-auc:0.82718	fold1-logloss:0.49964
# [138]	train-auc:0.90070	train-logloss:0.45817	fold1-auc:0.82756	fold1-logloss:0.49938
# [139]	train-auc:0.90125	train-logloss:0.45766	fold1-auc:0.82788	fold1-logloss:0.49910
# [140]	train-auc:0.90182	train-logloss:0.45710	fold1-auc:0.82844	fold1-logloss:0.49873
# [141]	train-auc:0.90218	train-logloss:0.45678	fold1-auc:0.82854	fold1-logloss:0.49856
# [142]	train-auc:0.90267	train-logloss:0.45626	fold1-auc:0.82860	fold1-logloss:0.49843
# [143]	train-auc:0.90309	train-logloss:0.45585	fold1-auc:0.82866	fold1-logloss:0.49829
# [144]	train-auc:0.90363	train-logloss:0.45534	fold1-auc:0.82903	fold1-logloss:0.49796
# [145]	train-auc:0.90424	train-logloss:0.45481	fold1-auc:0.82967	fold1-logloss:0.49754
# [146]	train-auc:0.90486	train-logloss:0.45391	fold1-auc:0.83027	fold1-logloss:0.49695
# [147]	train-auc:0.90559	train-logloss:0.45313	fold1-auc:0.83043	fold1-logloss:0.49669
# [148]	train-auc:0.90583	train-logloss:0.45276	fold1-auc:0.83053	fold1-logloss:0.49651
# [149]	train-auc:0.90641	train-logloss:0.45229	fold1-auc:0.83099	fold1-logloss:0.49623
# [150]	train-auc:0.90675	train-logloss:0.45183	fold1-auc:0.83107	fold1-logloss:0.49599
# [151]	train-auc:0.90752	train-logloss:0.45118	fold1-auc:0.83132	fold1-logloss:0.49567
# [152]	train-auc:0.90819	train-logloss:0.45026	fold1-auc:0.83214	fold1-logloss:0.49498
# [153]	train-auc:0.90879	train-logloss:0.44958	fold1-auc:0.83262	fold1-logloss:0.49458
# [154]	train-auc:0.90963	train-logloss:0.44886	fold1-auc:0.83370	fold1-logloss:0.49391
# [155]	train-auc:0.91032	train-logloss:0.44798	fold1-auc:0.83463	fold1-logloss:0.49312
# [156]	train-auc:0.91083	train-logloss:0.44740	fold1-auc:0.83431	fold1-logloss:0.49303
# [157]	train-auc:0.91121	train-logloss:0.44690	fold1-auc:0.83419	fold1-logloss:0.49292
# [158]	train-auc:0.91190	train-logloss:0.44626	fold1-auc:0.83468	fold1-logloss:0.49252
# [159]	train-auc:0.91208	train-logloss:0.44589	fold1-auc:0.83471	fold1-logloss:0.49230
# [160]	train-auc:0.91258	train-logloss:0.44518	fold1-auc:0.83525	fold1-logloss:0.49182
# [161]	train-auc:0.91338	train-logloss:0.44439	fold1-auc:0.83580	fold1-logloss:0.49138
# [162]	train-auc:0.91407	train-logloss:0.44391	fold1-auc:0.83628	fold1-logloss:0.49118
# [163]	train-auc:0.91441	train-logloss:0.44340	fold1-auc:0.83629	fold1-logloss:0.49098
# [164]	train-auc:0.91486	train-logloss:0.44296	fold1-auc:0.83617	fold1-logloss:0.49092
# [165]	train-auc:0.91550	train-logloss:0.44217	fold1-auc:0.83655	fold1-logloss:0.49043
# [166]	train-auc:0.91604	train-logloss:0.44175	fold1-auc:0.83702	fold1-logloss:0.49015
# [167]	train-auc:0.91671	train-logloss:0.44116	fold1-auc:0.83695	fold1-logloss:0.48998
# [168]	train-auc:0.91699	train-logloss:0.44076	fold1-auc:0.83714	fold1-logloss:0.48970
# [169]	train-auc:0.91763	train-logloss:0.44027	fold1-auc:0.83746	fold1-logloss:0.48953
# [170]	train-auc:0.91803	train-logloss:0.43974	fold1-auc:0.83753	fold1-logloss:0.48936
# [171]	train-auc:0.91826	train-logloss:0.43910	fold1-auc:0.83764	fold1-logloss:0.48902
# [172]	train-auc:0.91874	train-logloss:0.43862	fold1-auc:0.83767	fold1-logloss:0.48889
# [235]	train-auc:0.94128	train-logloss:0.40610	fold1-auc:0.85749	fold1-logloss:0.46796
# [236]	train-auc:0.94162	train-logloss:0.40539	fold1-auc:0.85815	fold1-logloss:0.46729
# [237]	train-auc:0.94202	train-logloss:0.40476	fold1-auc:0.85881	fold1-logloss:0.46674
# [238]	train-auc:0.94231	train-logloss:0.40435	fold1-auc:0.85918	fold1-logloss:0.46642
# [239]	train-auc:0.94267	train-logloss:0.40374	fold1-auc:0.85961	fold1-logloss:0.46590
# [240]	train-auc:0.94313	train-logloss:0.40312	fold1-auc:0.85969	fold1-logloss:0.46569
# [241]	train-auc:0.94330	train-logloss:0.40290	fold1-auc:0.85978	fold1-logloss:0.46556
# [242]	train-auc:0.94363	train-logloss:0.40224	fold1-auc:0.86015	fold1-logloss:0.46514
# [243]	train-auc:0.94376	train-logloss:0.40184	fold1-auc:0.86037	fold1-logloss:0.46485
# [244]	train-auc:0.94416	train-logloss:0.40138	fold1-auc:0.86036	fold1-logloss:0.46478
# [245]	train-auc:0.94448	train-logloss:0.40099	fold1-auc:0.86050	fold1-logloss:0.46465
# [246]	train-auc:0.94482	train-logloss:0.40045	fold1-auc:0.86056	fold1-logloss:0.46444
# [247]	train-auc:0.94508	train-logloss:0.40006	fold1-auc:0.86068	fold1-logloss:0.46421
# [248]	train-auc:0.94531	train-logloss:0.39959	fold1-auc:0.86090	fold1-logloss:0.46391
# [249]	train-auc:0.94575	train-logloss:0.39909	fold1-auc:0.86119	fold1-logloss:0.46373
# [250]	train-auc:0.94588	train-logloss:0.39888	fold1-auc:0.86145	fold1-logloss:0.46354
# [251]	train-auc:0.94628	train-logloss:0.39825	fold1-auc:0.86147	fold1-logloss:0.46328
# [252]	train-auc:0.94656	train-logloss:0.39787	fold1-auc:0.86176	fold1-logloss:0.46308
# [253]	train-auc:0.94670	train-logloss:0.39756	fold1-auc:0.86168	fold1-logloss:0.46300
# [254]	train-auc:0.94679	train-logloss:0.39730	fold1-auc:0.86184	fold1-logloss:0.46279
# [255]	train-auc:0.94712	train-logloss:0.39673	fold1-auc:0.86212	fold1-logloss:0.46245
# [256]	train-auc:0.94744	train-logloss:0.39636	fold1-auc:0.86219	fold1-logloss:0.46231
# [257]	train-auc:0.94755	train-logloss:0.39600	fold1-auc:0.86220	fold1-logloss:0.46209
# [258]	train-auc:0.94768	train-logloss:0.39545	fold1-auc:0.86242	fold1-logloss:0.46171
# [259]	train-auc:0.94819	train-logloss:0.39481	fold1-auc:0.86276	fold1-logloss:0.46142
# [260]	train-auc:0.94842	train-logloss:0.39447	fold1-auc:0.86307	fold1-logloss:0.46115
# [261]	train-auc:0.94867	train-logloss:0.39386	fold1-auc:0.86319	fold1-logloss:0.46082
# [262]	train-auc:0.94890	train-logloss:0.39327	fold1-auc:0.86333	fold1-logloss:0.46057
# [263]	train-auc:0.94945	train-logloss:0.39249	fold1-auc:0.86427	fold1-logloss:0.45981
# [264]	train-auc:0.94961	train-logloss:0.39223	fold1-auc:0.86417	fold1-logloss:0.45977
# [265]	train-auc:0.94972	train-logloss:0.39182	fold1-auc:0.86424	fold1-logloss:0.45954
# [266]	train-auc:0.94982	train-logloss:0.39156	fold1-auc:0.86427	fold1-logloss:0.45951
# [267]	train-auc:0.95006	train-logloss:0.39105	fold1-auc:0.86433	fold1-logloss:0.45925
# [268]	train-auc:0.95034	train-logloss:0.39052	fold1-auc:0.86461	fold1-logloss:0.45893
# [269]	train-auc:0.95060	train-logloss:0.39017	fold1-auc:0.86463	fold1-logloss:0.45896
# [270]	train-auc:0.95100	train-logloss:0.38969	fold1-auc:0.86505	fold1-logloss:0.45862
# [271]	train-auc:0.95097	train-logloss:0.38940	fold1-auc:0.86485	fold1-logloss:0.45855
# [272]	train-auc:0.95115	train-logloss:0.38885	fold1-auc:0.86518	fold1-logloss:0.45818
# [273]	train-auc:0.95122	train-logloss:0.38856	fold1-auc:0.86521	fold1-logloss:0.45801
# [274]	train-auc:0.95151	train-logloss:0.38811	fold1-auc:0.86567	fold1-logloss:0.45766
# [275]	train-auc:0.95186	train-logloss:0.38771	fold1-auc:0.86600	fold1-logloss:0.45743
# [276]	train-auc:0.95213	train-logloss:0.38725	fold1-auc:0.86634	fold1-logloss:0.45709
# [277]	train-auc:0.95228	train-logloss:0.38680	fold1-auc:0.86650	fold1-logloss:0.45679
# [278]	train-auc:0.95257	train-logloss:0.38637	fold1-auc:0.86669	fold1-logloss:0.45664
# [279]	train-auc:0.95267	train-logloss:0.38612	fold1-auc:0.86676	fold1-logloss:0.45647
# [280]	train-auc:0.95287	train-logloss:0.38574	fold1-auc:0.86702	fold1-logloss:0.45630
# [281]	train-auc:0.95318	train-logloss:0.38539	fold1-auc:0.86711	fold1-logloss:0.45618
# [282]	train-auc:0.95351	train-logloss:0.38500	fold1-auc:0.86737	fold1-logloss:0.45599
# [283]	train-auc:0.95379	train-logloss:0.38444	fold1-auc:0.86798	fold1-logloss:0.45541
# [284]	train-auc:0.95399	train-logloss:0.38418	fold1-auc:0.86834	fold1-logloss:0.45519
# [285]	train-auc:0.95417	train-logloss:0.38395	fold1-auc:0.86858	fold1-logloss:0.45503
# [286]	train-auc:0.95439	train-logloss:0.38366	fold1-auc:0.86841	fold1-logloss:0.45512
# [287]	train-auc:0.95451	train-logloss:0.38328	fold1-auc:0.86843	fold1-logloss:0.45497
# [288]	train-auc:0.95464	train-logloss:0.38281	fold1-auc:0.86886	fold1-logloss:0.45450
# [289]	train-auc:0.95502	train-logloss:0.38217	fold1-auc:0.86940	fold1-logloss:0.45400
# [290]	train-auc:0.95517	train-logloss:0.38187	fold1-auc:0.86928	fold1-logloss:0.45405
# [291]	train-auc:0.95527	train-logloss:0.38149	fold1-auc:0.86938	fold1-logloss:0.45386
# [292]	train-auc:0.95568	train-logloss:0.38097	fold1-auc:0.86927	fold1-logloss:0.45388
# [293]	train-auc:0.95584	train-logloss:0.38068	fold1-auc:0.86924	fold1-logloss:0.45381
# [294]	train-auc:0.95585	train-logloss:0.38036	fold1-auc:0.86928	fold1-logloss:0.45357
# [295]	train-auc:0.95628	train-logloss:0.37961	fold1-auc:0.86973	fold1-logloss:0.45302
# [296]	train-auc:0.95651	train-logloss:0.37901	fold1-auc:0.87021	fold1-logloss:0.45259
# [297]	train-auc:0.95692	train-logloss:0.37841	fold1-auc:0.87036	fold1-logloss:0.45229
# [298]	train-auc:0.95714	train-logloss:0.37789	fold1-auc:0.87068	fold1-logloss:0.45196
# [299]	train-auc:0.95742	train-logloss:0.37735	fold1-auc:0.87107	fold1-logloss:0.45155
# [300]	train-auc:0.95752	train-logloss:0.37707	fold1-auc:0.87103	fold1-logloss:0.45144
# [301]	train-auc:0.95789	train-logloss:0.37647	fold1-auc:0.87169	fold1-logloss:0.45093
# [302]	train-auc:0.95812	train-logloss:0.37609	fold1-auc:0.87170	fold1-logloss:0.45082
# [303]	train-auc:0.95843	train-logloss:0.37562	fold1-auc:0.87185	fold1-logloss:0.45062
# [304]	train-auc:0.95854	train-logloss:0.37536	fold1-auc:0.87193	fold1-logloss:0.45046
# [305]	train-auc:0.95861	train-logloss:0.37492	fold1-auc:0.87224	fold1-logloss:0.45003
# [306]	train-auc:0.95877	train-logloss:0.37465	fold1-auc:0.87234	fold1-logloss:0.44992
# [307]	train-auc:0.95891	train-logloss:0.37417	fold1-auc:0.87234	fold1-logloss:0.44973
# [308]	train-auc:0.95914	train-logloss:0.37386	fold1-auc:0.87223	fold1-logloss:0.44980
# [309]	train-auc:0.95933	train-logloss:0.37357	fold1-auc:0.87240	fold1-logloss:0.44965
# [310]	train-auc:0.95964	train-logloss:0.37311	fold1-auc:0.87287	fold1-logloss:0.44928
# [311]	train-auc:0.95986	train-logloss:0.37260	fold1-auc:0.87318	fold1-logloss:0.44892
# [312]	train-auc:0.96023	train-logloss:0.37202	fold1-auc:0.87344	fold1-logloss:0.44858
# [313]	train-auc:0.96052	train-logloss:0.37146	fold1-auc:0.87402	fold1-logloss:0.44807
# [314]	train-auc:0.96065	train-logloss:0.37113	fold1-auc:0.87419	fold1-logloss:0.44785
# [315]	train-auc:0.96095	train-logloss:0.37067	fold1-auc:0.87449	fold1-logloss:0.44758
# [316]	train-auc:0.96112	train-logloss:0.37028	fold1-auc:0.87482	fold1-logloss:0.44725
# [317]	train-auc:0.96118	train-logloss:0.36998	fold1-auc:0.87487	fold1-logloss:0.44710
# [318]	train-auc:0.96135	train-logloss:0.36960	fold1-auc:0.87522	fold1-logloss:0.44679
# [319]	train-auc:0.96146	train-logloss:0.36943	fold1-auc:0.87537	fold1-logloss:0.44667
# [320]	train-auc:0.96160	train-logloss:0.36910	fold1-auc:0.87552	fold1-logloss:0.44649
# [321]	train-auc:0.96178	train-logloss:0.36886	fold1-auc:0.87580	fold1-logloss:0.44637
# [322]	train-auc:0.96206	train-logloss:0.36835	fold1-auc:0.87561	fold1-logloss:0.44629
# [323]	train-auc:0.96211	train-logloss:0.36807	fold1-auc:0.87569	fold1-logloss:0.44608
# [324]	train-auc:0.96238	train-logloss:0.36752	fold1-auc:0.87568	fold1-logloss:0.44590
# [325]	train-auc:0.96256	train-logloss:0.36704	fold1-auc:0.87578	fold1-logloss:0.44566
# [326]	train-auc:0.96270	train-logloss:0.36671	fold1-auc:0.87605	fold1-logloss:0.44541
# [327]	train-auc:0.96277	train-logloss:0.36633	fold1-auc:0.87607	fold1-logloss:0.44521
# [328]	train-auc:0.96301	train-logloss:0.36588	fold1-auc:0.87622	fold1-logloss:0.44501
# [329]	train-auc:0.96322	train-logloss:0.36546	fold1-auc:0.87616	fold1-logloss:0.44494
# [330]	train-auc:0.96330	train-logloss:0.36535	fold1-auc:0.87622	fold1-logloss:0.44484
# [331]	train-auc:0.96351	train-logloss:0.36498	fold1-auc:0.87639	fold1-logloss:0.44460
# [332]	train-auc:0.96388	train-logloss:0.36439	fold1-auc:0.87672	fold1-logloss:0.44431
# [333]	train-auc:0.96407	train-logloss:0.36406	fold1-auc:0.87694	fold1-logloss:0.44414
# [334]	train-auc:0.96428	train-logloss:0.36367	fold1-auc:0.87715	fold1-logloss:0.44395
# [335]	train-auc:0.96440	train-logloss:0.36328	fold1-auc:0.87716	fold1-logloss:0.44381
# [336]	train-auc:0.96457	train-logloss:0.36273	fold1-auc:0.87731	fold1-logloss:0.44352
# [337]	train-auc:0.96471	train-logloss:0.36244	fold1-auc:0.87744	fold1-logloss:0.44339
# [338]	train-auc:0.96480	train-logloss:0.36223	fold1-auc:0.87752	fold1-logloss:0.44334
# [339]	train-auc:0.96499	train-logloss:0.36181	fold1-auc:0.87799	fold1-logloss:0.44284
# [340]	train-auc:0.96509	train-logloss:0.36134	fold1-auc:0.87777	fold1-logloss:0.44276
# [341]	train-auc:0.96513	train-logloss:0.36105	fold1-auc:0.87776	fold1-logloss:0.44259
# [342]	train-auc:0.96523	train-logloss:0.36083	fold1-auc:0.87780	fold1-logloss:0.44254
# [343]	train-auc:0.96539	train-logloss:0.36046	fold1-auc:0.87790	fold1-logloss:0.44248
# [344]	train-auc:0.96545	train-logloss:0.36024	fold1-auc:0.87795	fold1-logloss:0.44229
# [345]	train-auc:0.96567	train-logloss:0.35980	fold1-auc:0.87839	fold1-logloss:0.44196
# [346]	train-auc:0.96581	train-logloss:0.35939	fold1-auc:0.87882	fold1-logloss:0.44149
# [347]	train-auc:0.96589	train-logloss:0.35912	fold1-auc:0.87899	fold1-logloss:0.44128
# [348]	train-auc:0.96597	train-logloss:0.35886	fold1-auc:0.87906	fold1-logloss:0.44110
# [349]	train-auc:0.96602	train-logloss:0.35869	fold1-auc:0.87904	fold1-logloss:0.44099
# [350]	train-auc:0.96613	train-logloss:0.35802	fold1-auc:0.87934	fold1-logloss:0.44041
# [351]	train-auc:0.96620	train-logloss:0.35770	fold1-auc:0.87943	fold1-logloss:0.44027
# [352]	train-auc:0.96646	train-logloss:0.35723	fold1-auc:0.87984	fold1-logloss:0.43987
# [353]	train-auc:0.96663	train-logloss:0.35691	fold1-auc:0.87974	fold1-logloss:0.43985
# [354]	train-auc:0.96690	train-logloss:0.35644	fold1-auc:0.87992	fold1-logloss:0.43968
# [355]	train-auc:0.96702	train-logloss:0.35617	fold1-auc:0.88016	fold1-logloss:0.43947
# [356]	train-auc:0.96707	train-logloss:0.35604	fold1-auc:0.88030	fold1-logloss:0.43935
# [357]	train-auc:0.96737	train-logloss:0.35553	fold1-auc:0.88072	fold1-logloss:0.43892
# [358]	train-auc:0.96744	train-logloss:0.35531	fold1-auc:0.88063	fold1-logloss:0.43887
# [359]	train-auc:0.96751	train-logloss:0.35499	fold1-auc:0.88058	fold1-logloss:0.43878
# [360]	train-auc:0.96766	train-logloss:0.35457	fold1-auc:0.88055	fold1-logloss:0.43869
# [361]	train-auc:0.96788	train-logloss:0.35408	fold1-auc:0.88091	fold1-logloss:0.43838
# [362]	train-auc:0.96809	train-logloss:0.35367	fold1-auc:0.88094	fold1-logloss:0.43830
# [363]	train-auc:0.96830	train-logloss:0.35323	fold1-auc:0.88117	fold1-logloss:0.43810
# [364]	train-auc:0.96853	train-logloss:0.35284	fold1-auc:0.88136	fold1-logloss:0.43787
# [365]	train-auc:0.96862	train-logloss:0.35263	fold1-auc:0.88146	fold1-logloss:0.43774
# [366]	train-auc:0.96884	train-logloss:0.35222	fold1-auc:0.88183	fold1-logloss:0.43747
# [367]	train-auc:0.96903	train-logloss:0.35164	fold1-auc:0.88209	fold1-logloss:0.43703
# [368]	train-auc:0.96914	train-logloss:0.35139	fold1-auc:0.88198	fold1-logloss:0.43702
# [369]	train-auc:0.96929	train-logloss:0.35114	fold1-auc:0.88205	fold1-logloss:0.43692
# [370]	train-auc:0.96946	train-logloss:0.35070	fold1-auc:0.88229	fold1-logloss:0.43663
# [371]	train-auc:0.96953	train-logloss:0.35040	fold1-auc:0.88266	fold1-logloss:0.43628
# [372]	train-auc:0.96977	train-logloss:0.34999	fold1-auc:0.88281	fold1-logloss:0.43611
# [373]	train-auc:0.96982	train-logloss:0.34984	fold1-auc:0.88283	fold1-logloss:0.43604
# [374]	train-auc:0.96997	train-logloss:0.34950	fold1-auc:0.88286	fold1-logloss:0.43587
# [375]	train-auc:0.97008	train-logloss:0.34924	fold1-auc:0.88288	fold1-logloss:0.43581
# [376]	train-auc:0.97015	train-logloss:0.34900	fold1-auc:0.88305	fold1-logloss:0.43559
# [377]	train-auc:0.97023	train-logloss:0.34881	fold1-auc:0.88321	fold1-logloss:0.43547
# [378]	train-auc:0.97041	train-logloss:0.34843	fold1-auc:0.88327	fold1-logloss:0.43529
# [379]	train-auc:0.97048	train-logloss:0.34809	fold1-auc:0.88358	fold1-logloss:0.43491
# [380]	train-auc:0.97054	train-logloss:0.34790	fold1-auc:0.88368	fold1-logloss:0.43480
# [381]	train-auc:0.97065	train-logloss:0.34742	fold1-auc:0.88387	fold1-logloss:0.43449
# [382]	train-auc:0.97074	train-logloss:0.34714	fold1-auc:0.88395	fold1-logloss:0.43435
# [383]	train-auc:0.97096	train-logloss:0.34677	fold1-auc:0.88430	fold1-logloss:0.43408
# [384]	train-auc:0.97110	train-logloss:0.34642	fold1-auc:0.88426	fold1-logloss:0.43402
# [385]	train-auc:0.97118	train-logloss:0.34612	fold1-auc:0.88428	fold1-logloss:0.43393
# [386]	train-auc:0.97137	train-logloss:0.34576	fold1-auc:0.88431	fold1-logloss:0.43380
# [387]	train-auc:0.97140	train-logloss:0.34559	fold1-auc:0.88434	fold1-logloss:0.43375
# [388]	train-auc:0.97154	train-logloss:0.34522	fold1-auc:0.88425	fold1-logloss:0.43372
# [389]	train-auc:0.97162	train-logloss:0.34496	fold1-auc:0.88411	fold1-logloss:0.43373
# [390]	train-auc:0.97174	train-logloss:0.34458	fold1-auc:0.88398	fold1-logloss:0.43362
# [391]	train-auc:0.97195	train-logloss:0.34412	fold1-auc:0.88393	fold1-logloss:0.43356
# [392]	train-auc:0.97209	train-logloss:0.34376	fold1-auc:0.88415	fold1-logloss:0.43337
# [393]	train-auc:0.97222	train-logloss:0.34344	fold1-auc:0.88409	fold1-logloss:0.43334
# [394]	train-auc:0.97242	train-logloss:0.34296	fold1-auc:0.88450	fold1-logloss:0.43296
# [395]	train-auc:0.97264	train-logloss:0.34264	fold1-auc:0.88470	fold1-logloss:0.43280
# [396]	train-auc:0.97272	train-logloss:0.34215	fold1-auc:0.88488	fold1-logloss:0.43247
# [397]	train-auc:0.97280	train-logloss:0.34189	fold1-auc:0.88474	fold1-logloss:0.43246
# [398]	train-auc:0.97296	train-logloss:0.34136	fold1-auc:0.88529	fold1-logloss:0.43191
# [399]	train-auc:0.97304	train-logloss:0.34102	fold1-auc:0.88545	fold1-logloss:0.43166
# [400]	train-auc:0.97320	train-logloss:0.34052	fold1-auc:0.88538	fold1-logloss:0.43158
# [401]	train-auc:0.97331	train-logloss:0.34023	fold1-auc:0.88535	fold1-logloss:0.43148
# [402]	train-auc:0.97346	train-logloss:0.33987	fold1-auc:0.88541	fold1-logloss:0.43141
# [403]	train-auc:0.97358	train-logloss:0.33948	fold1-auc:0.88572	fold1-logloss:0.43118
# [404]	train-auc:0.97375	train-logloss:0.33912	fold1-auc:0.88571	fold1-logloss:0.43108
# [405]	train-auc:0.97386	train-logloss:0.33893	fold1-auc:0.88566	fold1-logloss:0.43106
# [406]	train-auc:0.97393	train-logloss:0.33852	fold1-auc:0.88594	fold1-logloss:0.43068
# [407]	train-auc:0.97402	train-logloss:0.33825	fold1-auc:0.88612	fold1-logloss:0.43039
# [408]	train-auc:0.97419	train-logloss:0.33781	fold1-auc:0.88668	fold1-logloss:0.42987
# [409]	train-auc:0.97439	train-logloss:0.33734	fold1-auc:0.88699	fold1-logloss:0.42960
# [410]	train-auc:0.97441	train-logloss:0.33710	fold1-auc:0.88703	fold1-logloss:0.42947
# [411]	train-auc:0.97464	train-logloss:0.33659	fold1-auc:0.88724	fold1-logloss:0.42913
# [412]	train-auc:0.97473	train-logloss:0.33632	fold1-auc:0.88722	fold1-logloss:0.42903
# [413]	train-auc:0.97488	train-logloss:0.33590	fold1-auc:0.88745	fold1-logloss:0.42873
# [414]	train-auc:0.97496	train-logloss:0.33553	fold1-auc:0.88766	fold1-logloss:0.42834
# [415]	train-auc:0.97509	train-logloss:0.33523	fold1-auc:0.88773	fold1-logloss:0.42823
# [416]	train-auc:0.97522	train-logloss:0.33482	fold1-auc:0.88801	fold1-logloss:0.42793
# [417]	train-auc:0.97538	train-logloss:0.33444	fold1-auc:0.88820	fold1-logloss:0.42763
# [418]	train-auc:0.97542	train-logloss:0.33421	fold1-auc:0.88812	fold1-logloss:0.42753
# [419]	train-auc:0.97552	train-logloss:0.33384	fold1-auc:0.88845	fold1-logloss:0.42719
# [420]	train-auc:0.97561	train-logloss:0.33354	fold1-auc:0.88844	fold1-logloss:0.42706
# [421]	train-auc:0.97570	train-logloss:0.33324	fold1-auc:0.88849	fold1-logloss:0.42692
# [422]	train-auc:0.97585	train-logloss:0.33289	fold1-auc:0.88866	fold1-logloss:0.42672
# [423]	train-auc:0.97600	train-logloss:0.33256	fold1-auc:0.88885	fold1-logloss:0.42657
# [424]	train-auc:0.97610	train-logloss:0.33233	fold1-auc:0.88906	fold1-logloss:0.42637
# [425]	train-auc:0.97614	train-logloss:0.33206	fold1-auc:0.88907	fold1-logloss:0.42633
# [426]	train-auc:0.97620	train-logloss:0.33167	fold1-auc:0.88930	fold1-logloss:0.42603
# [427]	train-auc:0.97632	train-logloss:0.33135	fold1-auc:0.88943	fold1-logloss:0.42592
# [428]	train-auc:0.97644	train-logloss:0.33095	fold1-auc:0.88959	fold1-logloss:0.42565
# [429]	train-auc:0.97646	train-logloss:0.33077	fold1-auc:0.88978	fold1-logloss:0.42548
# [430]	train-auc:0.97651	train-logloss:0.33056	fold1-auc:0.88983	fold1-logloss:0.42530
# [431]	train-auc:0.97660	train-logloss:0.33013	fold1-auc:0.89009	fold1-logloss:0.42494
# [432]	train-auc:0.97668	train-logloss:0.32995	fold1-auc:0.89014	fold1-logloss:0.42489
# [433]	train-auc:0.97676	train-logloss:0.32953	fold1-auc:0.89008	fold1-logloss:0.42476
# [434]	train-auc:0.97684	train-logloss:0.32911	fold1-auc:0.89013	fold1-logloss:0.42454
# [435]	train-auc:0.97696	train-logloss:0.32883	fold1-auc:0.89027	fold1-logloss:0.42439
# [436]	train-auc:0.97705	train-logloss:0.32863	fold1-auc:0.89024	fold1-logloss:0.42431
# [437]	train-auc:0.97721	train-logloss:0.32821	fold1-auc:0.89044	fold1-logloss:0.42407
# [438]	train-auc:0.97724	train-logloss:0.32796	fold1-auc:0.89034	fold1-logloss:0.42402
# [439]	train-auc:0.97733	train-logloss:0.32763	fold1-auc:0.89052	fold1-logloss:0.42383
# [440]	train-auc:0.97742	train-logloss:0.32704	fold1-auc:0.89097	fold1-logloss:0.42326
# [441]	train-auc:0.97759	train-logloss:0.32663	fold1-auc:0.89119	fold1-logloss:0.42303
# [442]	train-auc:0.97771	train-logloss:0.32627	fold1-auc:0.89131	fold1-logloss:0.42285
# [443]	train-auc:0.97784	train-logloss:0.32590	fold1-auc:0.89160	fold1-logloss:0.42259
# [444]	train-auc:0.97793	train-logloss:0.32563	fold1-auc:0.89152	fold1-logloss:0.42253
# [445]	train-auc:0.97799	train-logloss:0.32540	fold1-auc:0.89174	fold1-logloss:0.42233
# [446]	train-auc:0.97809	train-logloss:0.32493	fold1-auc:0.89194	fold1-logloss:0.42202
# [447]	train-auc:0.97813	train-logloss:0.32472	fold1-auc:0.89192	fold1-logloss:0.42194
# [448]	train-auc:0.97831	train-logloss:0.32427	fold1-auc:0.89213	fold1-logloss:0.42166
# [449]	train-auc:0.97845	train-logloss:0.32384	fold1-auc:0.89238	fold1-logloss:0.42134
# [450]	train-auc:0.97860	train-logloss:0.32338	fold1-auc:0.89267	fold1-logloss:0.42102
# [451]	train-auc:0.97868	train-logloss:0.32307	fold1-auc:0.89273	fold1-logloss:0.42084
# [452]	train-auc:0.97876	train-logloss:0.32275	fold1-auc:0.89289	fold1-logloss:0.42066
# [453]	train-auc:0.97879	train-logloss:0.32236	fold1-auc:0.89308	fold1-logloss:0.42038
# [454]	train-auc:0.97890	train-logloss:0.32204	fold1-auc:0.89317	fold1-logloss:0.42030
# [455]	train-auc:0.97898	train-logloss:0.32167	fold1-auc:0.89334	fold1-logloss:0.42003
# [456]	train-auc:0.97911	train-logloss:0.32136	fold1-auc:0.89361	fold1-logloss:0.41980
# [457]	train-auc:0.97927	train-logloss:0.32099	fold1-auc:0.89373	fold1-logloss:0.41972
# [458]	train-auc:0.97936	train-logloss:0.32059	fold1-auc:0.89384	fold1-logloss:0.41943
# [459]	train-auc:0.97943	train-logloss:0.32027	fold1-auc:0.89402	fold1-logloss:0.41915
# [460]	train-auc:0.97953	train-logloss:0.32002	fold1-auc:0.89416	fold1-logloss:0.41900
# [461]	train-auc:0.97965	train-logloss:0.31978	fold1-auc:0.89414	fold1-logloss:0.41897
# [462]	train-auc:0.97978	train-logloss:0.31935	fold1-auc:0.89424	fold1-logloss:0.41878
# [463]	train-auc:0.97985	train-logloss:0.31895	fold1-auc:0.89459	fold1-logloss:0.41834
# [464]	train-auc:0.97990	train-logloss:0.31871	fold1-auc:0.89451	fold1-logloss:0.41827
# [465]	train-auc:0.98004	train-logloss:0.31836	fold1-auc:0.89452	fold1-logloss:0.41821
# [466]	train-auc:0.98011	train-logloss:0.31798	fold1-auc:0.89451	fold1-logloss:0.41803
# [467]	train-auc:0.98011	train-logloss:0.31775	fold1-auc:0.89451	fold1-logloss:0.41790
# [468]	train-auc:0.98019	train-logloss:0.31746	fold1-auc:0.89454	fold1-logloss:0.41780
# [469]	train-auc:0.98034	train-logloss:0.31704	fold1-auc:0.89481	fold1-logloss:0.41749
# [470]	train-auc:0.98041	train-logloss:0.31664	fold1-auc:0.89494	fold1-logloss:0.41722
# [471]	train-auc:0.98053	train-logloss:0.31638	fold1-auc:0.89499	fold1-logloss:0.41716
# [472]	train-auc:0.98066	train-logloss:0.31598	fold1-auc:0.89530	fold1-logloss:0.41681
# [473]	train-auc:0.98075	train-logloss:0.31570	fold1-auc:0.89552	fold1-logloss:0.41656
# [474]	train-auc:0.98081	train-logloss:0.31547	fold1-auc:0.89562	fold1-logloss:0.41639
# [475]	train-auc:0.98090	train-logloss:0.31516	fold1-auc:0.89566	fold1-logloss:0.41624
# [476]	train-auc:0.98103	train-logloss:0.31480	fold1-auc:0.89560	fold1-logloss:0.41619
# [477]	train-auc:0.98121	train-logloss:0.31437	fold1-auc:0.89601	fold1-logloss:0.41582
# [478]	train-auc:0.98131	train-logloss:0.31383	fold1-auc:0.89608	fold1-logloss:0.41552
# [479]	train-auc:0.98144	train-logloss:0.31353	fold1-auc:0.89627	fold1-logloss:0.41537
# [480]	train-auc:0.98151	train-logloss:0.31322	fold1-auc:0.89635	fold1-logloss:0.41518
# [481]	train-auc:0.98164	train-logloss:0.31277	fold1-auc:0.89655	fold1-logloss:0.41484
# [482]	train-auc:0.98174	train-logloss:0.31258	fold1-auc:0.89657	fold1-logloss:0.41476
# [483]	train-auc:0.98175	train-logloss:0.31241	fold1-auc:0.89651	fold1-logloss:0.41474
# [484]	train-auc:0.98178	train-logloss:0.31216	fold1-auc:0.89666	fold1-logloss:0.41451
# [485]	train-auc:0.98180	train-logloss:0.31190	fold1-auc:0.89658	fold1-logloss:0.41444
# [486]	train-auc:0.98188	train-logloss:0.31164	fold1-auc:0.89665	fold1-logloss:0.41436
# [487]	train-auc:0.98195	train-logloss:0.31126	fold1-auc:0.89683	fold1-logloss:0.41413
# [488]	train-auc:0.98206	train-logloss:0.31100	fold1-auc:0.89700	fold1-logloss:0.41404
# [489]	train-auc:0.98212	train-logloss:0.31072	fold1-auc:0.89719	fold1-logloss:0.41376
# [490]	train-auc:0.98224	train-logloss:0.31040	fold1-auc:0.89737	fold1-logloss:0.41360
# [491]	train-auc:0.98240	train-logloss:0.30997	fold1-auc:0.89765	fold1-logloss:0.41331
# [492]	train-auc:0.98250	train-logloss:0.30968	fold1-auc:0.89766	fold1-logloss:0.41322
# [493]	train-auc:0.98263	train-logloss:0.30926	fold1-auc:0.89772	fold1-logloss:0.41308
# [494]	train-auc:0.98269	train-logloss:0.30888	fold1-auc:0.89798	fold1-logloss:0.41274
# [495]	train-auc:0.98279	train-logloss:0.30863	fold1-auc:0.89811	fold1-logloss:0.41263
# [496]	train-auc:0.98293	train-logloss:0.30826	fold1-auc:0.89833	fold1-logloss:0.41239
# [497]	train-auc:0.98296	train-logloss:0.30803	fold1-auc:0.89830	fold1-logloss:0.41227
# [498]	train-auc:0.98304	train-logloss:0.30759	fold1-auc:0.89859	fold1-logloss:0.41191
# [499]	train-auc:0.98313	train-logloss:0.30738	fold1-auc:0.89866	fold1-logloss:0.41179
# [500]	train-auc:0.98320	train-logloss:0.30710	fold1-auc:0.89869	fold1-logloss:0.41169
# [501]	train-auc:0.98333	train-logloss:0.30678	fold1-auc:0.89877	fold1-logloss:0.41156
# [502]	train-auc:0.98340	train-logloss:0.30641	fold1-auc:0.89904	fold1-logloss:0.41121
# [503]	train-auc:0.98348	train-logloss:0.30609	fold1-auc:0.89923	fold1-logloss:0.41087
# [504]	train-auc:0.98354	train-logloss:0.30580	fold1-auc:0.89906	fold1-logloss:0.41087
# [505]	train-auc:0.98362	train-logloss:0.30565	fold1-auc:0.89911	fold1-logloss:0.41081
# [506]	train-auc:0.98361	train-logloss:0.30547	fold1-auc:0.89922	fold1-logloss:0.41061
# [507]	train-auc:0.98370	train-logloss:0.30508	fold1-auc:0.89956	fold1-logloss:0.41019
# [508]	train-auc:0.98379	train-logloss:0.30460	fold1-auc:0.89969	fold1-logloss:0.40986
# [509]	train-auc:0.98385	train-logloss:0.30440	fold1-auc:0.89971	fold1-logloss:0.40978
# [510]	train-auc:0.98391	train-logloss:0.30417	fold1-auc:0.89991	fold1-logloss:0.40965
# [511]	train-auc:0.98398	train-logloss:0.30396	fold1-auc:0.89997	fold1-logloss:0.40955
# [512]	train-auc:0.98404	train-logloss:0.30358	fold1-auc:0.90016	fold1-logloss:0.40926
# [513]	train-auc:0.98404	train-logloss:0.30333	fold1-auc:0.90032	fold1-logloss:0.40899
# [514]	train-auc:0.98409	train-logloss:0.30300	fold1-auc:0.90051	fold1-logloss:0.40875
# [515]	train-auc:0.98411	train-logloss:0.30288	fold1-auc:0.90049	fold1-logloss:0.40870
# [516]	train-auc:0.98416	train-logloss:0.30260	fold1-auc:0.90069	fold1-logloss:0.40843
# [517]	train-auc:0.98424	train-logloss:0.30232	fold1-auc:0.90082	fold1-logloss:0.40827
# [518]	train-auc:0.98431	train-logloss:0.30198	fold1-auc:0.90117	fold1-logloss:0.40790
# [519]	train-auc:0.98436	train-logloss:0.30162	fold1-auc:0.90123	fold1-logloss:0.40768
# [520]	train-auc:0.98441	train-logloss:0.30132	fold1-auc:0.90113	fold1-logloss:0.40764
# [521]	train-auc:0.98446	train-logloss:0.30104	fold1-auc:0.90116	fold1-logloss:0.40754
# [522]	train-auc:0.98457	train-logloss:0.30062	fold1-auc:0.90121	fold1-logloss:0.40735
# [523]	train-auc:0.98462	train-logloss:0.30029	fold1-auc:0.90129	fold1-logloss:0.40716
# [524]	train-auc:0.98475	train-logloss:0.29993	fold1-auc:0.90139	fold1-logloss:0.40704
# [525]	train-auc:0.98487	train-logloss:0.29963	fold1-auc:0.90151	fold1-logloss:0.40698
# [526]	train-auc:0.98494	train-logloss:0.29938	fold1-auc:0.90158	fold1-logloss:0.40682
# [527]	train-auc:0.98497	train-logloss:0.29888	fold1-auc:0.90167	fold1-logloss:0.40646
# [528]	train-auc:0.98506	train-logloss:0.29849	fold1-auc:0.90181	fold1-logloss:0.40631
# [529]	train-auc:0.98515	train-logloss:0.29814	fold1-auc:0.90174	fold1-logloss:0.40631
# [530]	train-auc:0.98524	train-logloss:0.29783	fold1-auc:0.90193	fold1-logloss:0.40610
# [531]	train-auc:0.98532	train-logloss:0.29756	fold1-auc:0.90200	fold1-logloss:0.40599
# [532]	train-auc:0.98539	train-logloss:0.29739	fold1-auc:0.90206	fold1-logloss:0.40593
# [533]	train-auc:0.98546	train-logloss:0.29706	fold1-auc:0.90216	fold1-logloss:0.40573
# [534]	train-auc:0.98550	train-logloss:0.29675	fold1-auc:0.90231	fold1-logloss:0.40545
# [535]	train-auc:0.98555	train-logloss:0.29655	fold1-auc:0.90229	fold1-logloss:0.40544
# [536]	train-auc:0.98567	train-logloss:0.29617	fold1-auc:0.90249	fold1-logloss:0.40512
# [537]	train-auc:0.98577	train-logloss:0.29569	fold1-auc:0.90278	fold1-logloss:0.40472
# [538]	train-auc:0.98583	train-logloss:0.29541	fold1-auc:0.90299	fold1-logloss:0.40444
# [539]	train-auc:0.98593	train-logloss:0.29520	fold1-auc:0.90299	fold1-logloss:0.40442
# [540]	train-auc:0.98602	train-logloss:0.29493	fold1-auc:0.90304	fold1-logloss:0.40426
# [873]	train-auc:0.99768	train-logloss:0.21216	fold5-auc:0.92307	fold5-logloss:0.36007
# [874]	train-auc:0.99769	train-logloss:0.21193	fold5-auc:0.92304	fold5-logloss:0.36005
# [875]	train-auc:0.99771	train-logloss:0.21169	fold5-auc:0.92307	fold5-logloss:0.35996
# [876]	train-auc:0.99772	train-logloss:0.21148	fold5-auc:0.92305	fold5-logloss:0.35994
# [877]	train-auc:0.99773	train-logloss:0.21125	fold5-auc:0.92315	fold5-logloss:0.35972
# [878]	train-auc:0.99774	train-logloss:0.21108	fold5-auc:0.92323	fold5-logloss:0.35960
# [879]	train-auc:0.99775	train-logloss:0.21097	fold5-auc:0.92323	fold5-logloss:0.35961
# [880]	train-auc:0.99775	train-logloss:0.21084	fold5-auc:0.92327	fold5-logloss:0.35952
# [881]	train-auc:0.99776	train-logloss:0.21063	fold5-auc:0.92343	fold5-logloss:0.35926
# [882]	train-auc:0.99777	train-logloss:0.21037	fold5-auc:0.92357	fold5-logloss:0.35902
# [883]	train-auc:0.99778	train-logloss:0.21021	fold5-auc:0.92362	fold5-logloss:0.35895
# [884]	train-auc:0.99780	train-logloss:0.21003	fold5-auc:0.92372	fold5-logloss:0.35880
# [885]	train-auc:0.99780	train-logloss:0.20992	fold5-auc:0.92371	fold5-logloss:0.35878
# [886]	train-auc:0.99781	train-logloss:0.20969	fold5-auc:0.92384	fold5-logloss:0.35852
# [887]	train-auc:0.99781	train-logloss:0.20951	fold5-auc:0.92378	fold5-logloss:0.35852
# [888]	train-auc:0.99783	train-logloss:0.20927	fold5-auc:0.92377	fold5-logloss:0.35845
# [889]	train-auc:0.99784	train-logloss:0.20904	fold5-auc:0.92397	fold5-logloss:0.35817
# [890]	train-auc:0.99785	train-logloss:0.20870	fold5-auc:0.92416	fold5-logloss:0.35782
# [891]	train-auc:0.99784	train-logloss:0.20857	fold5-auc:0.92418	fold5-logloss:0.35776
# [892]	train-auc:0.99786	train-logloss:0.20836	fold5-auc:0.92427	fold5-logloss:0.35762
# [893]	train-auc:0.99787	train-logloss:0.20824	fold5-auc:0.92435	fold5-logloss:0.35748
# [894]	train-auc:0.99788	train-logloss:0.20808	fold5-auc:0.92439	fold5-logloss:0.35738
# [895]	train-auc:0.99790	train-logloss:0.20783	fold5-auc:0.92450	fold5-logloss:0.35722
# [896]	train-auc:0.99790	train-logloss:0.20775	fold5-auc:0.92455	fold5-logloss:0.35716
# [897]	train-auc:0.99792	train-logloss:0.20752	fold5-auc:0.92460	fold5-logloss:0.35701
# [898]	train-auc:0.99793	train-logloss:0.20729	fold5-auc:0.92456	fold5-logloss:0.35697
# [899]	train-auc:0.99794	train-logloss:0.20718	fold5-auc:0.92453	fold5-logloss:0.35703
# [900]	train-auc:0.99795	train-logloss:0.20701	fold5-auc:0.92459	fold5-logloss:0.35693
# [901]	train-auc:0.99795	train-logloss:0.20679	fold5-auc:0.92462	fold5-logloss:0.35679
# [902]	train-auc:0.99796	train-logloss:0.20670	fold5-auc:0.92458	fold5-logloss:0.35679
# [903]	train-auc:0.99796	train-logloss:0.20652	fold5-auc:0.92467	fold5-logloss:0.35666
# [904]	train-auc:0.99798	train-logloss:0.20633	fold5-auc:0.92482	fold5-logloss:0.35648
# [905]	train-auc:0.99798	train-logloss:0.20619	fold5-auc:0.92488	fold5-logloss:0.35638
# [906]	train-auc:0.99801	train-logloss:0.20580	fold5-auc:0.92515	fold5-logloss:0.35597
# [907]	train-auc:0.99802	train-logloss:0.20560	fold5-auc:0.92519	fold5-logloss:0.35582
# [908]	train-auc:0.99802	train-logloss:0.20538	fold5-auc:0.92519	fold5-logloss:0.35573
# [909]	train-auc:0.99802	train-logloss:0.20514	fold5-auc:0.92525	fold5-logloss:0.35554
# [910]	train-auc:0.99803	train-logloss:0.20505	fold5-auc:0.92523	fold5-logloss:0.35554
# [911]	train-auc:0.99804	train-logloss:0.20480	fold5-auc:0.92528	fold5-logloss:0.35538
# [912]	train-auc:0.99804	train-logloss:0.20456	fold5-auc:0.92518	fold5-logloss:0.35528
# [913]	train-auc:0.99806	train-logloss:0.20436	fold5-auc:0.92530	fold5-logloss:0.35512
# [914]	train-auc:0.99807	train-logloss:0.20410	fold5-auc:0.92540	fold5-logloss:0.35488
# [915]	train-auc:0.99808	train-logloss:0.20389	fold5-auc:0.92542	fold5-logloss:0.35482
# [916]	train-auc:0.99810	train-logloss:0.20369	fold5-auc:0.92540	fold5-logloss:0.35477
# [917]	train-auc:0.99811	train-logloss:0.20350	fold5-auc:0.92546	fold5-logloss:0.35473
# [918]	train-auc:0.99812	train-logloss:0.20342	fold5-auc:0.92545	fold5-logloss:0.35472
# [919]	train-auc:0.99813	train-logloss:0.20314	fold5-auc:0.92555	fold5-logloss:0.35450
# [920]	train-auc:0.99814	train-logloss:0.20295	fold5-auc:0.92564	fold5-logloss:0.35439
# [921]	train-auc:0.99815	train-logloss:0.20277	fold5-auc:0.92575	fold5-logloss:0.35423
# [922]	train-auc:0.99816	train-logloss:0.20258	fold5-auc:0.92590	fold5-logloss:0.35409
# [923]	train-auc:0.99817	train-logloss:0.20245	fold5-auc:0.92598	fold5-logloss:0.35393
# [924]	train-auc:0.99817	train-logloss:0.20224	fold5-auc:0.92602	fold5-logloss:0.35379
# [925]	train-auc:0.99819	train-logloss:0.20201	fold5-auc:0.92610	fold5-logloss:0.35360
# [926]	train-auc:0.99819	train-logloss:0.20186	fold5-auc:0.92601	fold5-logloss:0.35361
# [927]	train-auc:0.99820	train-logloss:0.20169	fold5-auc:0.92611	fold5-logloss:0.35342
# [928]	train-auc:0.99822	train-logloss:0.20148	fold5-auc:0.92616	fold5-logloss:0.35339
# [929]	train-auc:0.99822	train-logloss:0.20135	fold5-auc:0.92619	fold5-logloss:0.35328
# [930]	train-auc:0.99824	train-logloss:0.20113	fold5-auc:0.92627	fold5-logloss:0.35317
# [931]	train-auc:0.99825	train-logloss:0.20105	fold5-auc:0.92626	fold5-logloss:0.35313
# [932]	train-auc:0.99827	train-logloss:0.20082	fold5-auc:0.92629	fold5-logloss:0.35302
# [933]	train-auc:0.99829	train-logloss:0.20060	fold5-auc:0.92638	fold5-logloss:0.35293
# [934]	train-auc:0.99830	train-logloss:0.20044	fold5-auc:0.92638	fold5-logloss:0.35290
